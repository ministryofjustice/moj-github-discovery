# %%
import pandas as pd

# %%
df = pd.read_excel("../res2.xlsx")
df.head()
# Out:
#                  org                           repo  \
# 0  ministryofjustice          hmpps-adjustments-api
# 1  ministryofjustice     hmpps-community-payback-ui
# 2  ministryofjustice                        opg-lpa
# 3  ministryofjustice                   opg-digideps
# 4  ministryofjustice  hmpps-digital-prison-services
#
#                                          full_name  private  archived   fork  \
# 0          ministryofjustice/hmpps-adjustments-api    False     False  False
# 1     ministryofjustice/hmpps-community-payback-ui    False     False  False
# 2                        ministryofjustice/opg-lpa    False     False  False
# 3                   ministryofjustice/opg-digideps    False     False  False
# 4  ministryofjustice/hmpps-digital-prison-services    False     False  False
#
#   fork_source  is_generated_from_template template_source  \
# 0         NaN                       False             NaN
# 1         NaN                       False             NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   org                         800 non-null    str
#  1   repo                        800 non-null    str
#  2   full_name                   800 non-null    str
#  3   private                     800 non-null    bool
#  4   archived                    800 non-null    bool
#  5   fork                        800 non-null    bool
#  6   fork_source                 8 non-null      str
#  7   is_generated_from_template  800 non-null    bool
#  8   template_source             4 non-null      str
#  9   pushed_at                   800 non-null    str
#  10  default_branch              800 non-null    str
#  11  language                    780 non-null    str
#  12  open_issues                 800 non-null    int64
#  13  stargazers                  800 non-null    int64
# ...

# %%
df["language"].value_counts(dropna=False)
# Out:
# language
# TypeScript          138
# Kotlin              127
# HCL                 100
# Python               92
# Java                 54
# HTML                 50
# JavaScript           39
# Ruby                 36
# Go                   26
# Shell                24
# NaN                  20
# Dockerfile           15
# PHP                  14
# C#                   12
# R                     9
# PLSQL                 7
# Nunjucks              6
# Makefile              5
# Gherkin               3
# CSS                   3
# PowerShell            2
# Jupyter Notebook      2
# PLpgSQL               2
# Go Template           2
# Smarty                2
# Lua                   1
# Mermaid               1
# Rich Text Format      1
# CoffeeScript          1
# VBScript              1
# YAML                  1
# C                     1
# Rust                  1
# Mustache              1
# XSLT                  1
# Name: count, dtype: int64

# %%
df[['private','archived', 'fork', 'is_generated_from_template', 'default_branch']].value_counts()
# Out:
# private  archived  fork   is_generated_from_template  default_branch
# False    False     False  False                       main              600
# True     False     False  False                       main              157
#                                                       master             11
# False    False     False  False                       master             10
#                    True   False                       main                6
# True     False     False  False                       develop             4
# False    False     False  True                        main                4
# True     False     False  False                       development         3
# False    False     False  False                       develop             2
#                    True   False                       master              1
#                                                       8.x                 1
# ...

# %%
df['pushed_at'].describe()
# Out:
# count                      800
# unique                     797
# top       2026-03-05T12:21:59Z
# freq                         2
# Name: pushed_at, dtype: object
